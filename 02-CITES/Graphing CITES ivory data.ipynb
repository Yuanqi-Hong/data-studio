# %%
import pandas as pd
import matplotlib.pyplot as plt
from cycler import cycler

# %% [markdown]
# Note on taxonomic ranks: kingdom > phylum or division > class > order > family > genus > species

# %%
teeth = pd.read_csv('CITES_data_20180717_teeth.csv')
teeth.head()
# Out:
#    Year App.               Taxon     Class        Order        Family  \
# 0  1977   II     Crocodylus spp.  Reptilia   Crocodylia  Crocodylidae
# 1  1978   II     Crocodylus spp.  Reptilia   Crocodylia  Crocodylidae
# 2  1978   II        Dugong dugon  Mammalia      Sirenia    Dugongidae
# 3  1978   II  Loxodonta africana  Mammalia  Proboscidea  Elephantidae
# 4  1978   II  Loxodonta africana  Mammalia  Proboscidea  Elephantidae
#
#         Genus Importer Exporter Origin  Importer reported quantity  \
# 0  Crocodylus       US       PG    NaN                         NaN
# 1  Crocodylus       AU       PG    NaN                         NaN
# 2      Dugong       US       AU    NaN                         NaN
# 3   Loxodonta       CH       DE     BW                         NaN
# 4   Loxodonta       DE       CH     XX                         NaN
#
#    Exporter reported quantity   Term Unit Purpose Source
# 0                         1.0  teeth  NaN     NaN    NaN
# ...

# %%
ivory = pd.read_csv('CITES_data_20180717_ivory_carvings.csv')
ivory.head()
# Out:
#    Year App.              Taxon     Class        Order        Family    Genus  \
# 0  1976    I    Elephas maximus  Mammalia  Proboscidea  Elephantidae  Elephas
# 1  1977    I    Elephas maximus  Mammalia  Proboscidea  Elephantidae  Elephas
# 2  1977   II  Elephantidae spp.  Mammalia  Proboscidea  Elephantidae      NaN
# 3  1977   II  Elephantidae spp.  Mammalia  Proboscidea  Elephantidae      NaN
# 4  1977   II  Elephantidae spp.  Mammalia  Proboscidea  Elephantidae      NaN
#
#   Importer Exporter Origin  Importer reported quantity  \
# 0       DE       IN    NaN                       142.0
# 1       CA       US    NaN                         1.0
# 2       DK       GB     XX                        60.0
# 3       DK       HK     XX                        22.0
# 4       DK       IN     XX                       144.0
#
#    Exporter reported quantity            Term  Unit Purpose Source
# 0                         NaN  ivory carvings   NaN       T    NaN
# ...

# %%
teeth[teeth['Genus']=='Mammuthus']
# Out:
# Empty DataFrame
# Columns: [Year, App., Taxon, Class, Order, Family, Genus, Importer, Exporter, Origin, Importer reported quantity, Exporter reported quantity, Term, Unit, Purpose, Source]
# Index: []

# %%
teeth[teeth['Family']=='Elephantidae'].Taxon.value_counts()
# Out:
# Loxodonta africana    482
# Elephas maximus        47
# Elephantidae spp.      39
# Elephas spp.            1
# Name: Taxon, dtype: int64

# %%
teeth[teeth['Family']=='Elephantidae'].shape
# Out:
# (569, 16)

# %%
teeth.Class.value_counts()
# Out:
# Mammalia          7822
# Reptilia           652
# Elasmobranchii      54
# Aves                 4
# Name: Class, dtype: int64

# %%
teeth.Order.value_counts()
# Out:
# Artiodactyla         3103
# Carnivora            2118
# Cetacea              1758
# Crocodylia            648
# Proboscidea           569
# Primates              184
# Perissodactyla         47
# Lamniformes            42
# Sirenia                19
# Rodentia               13
# Pristiformes           10
# Cingulata               6
# Chiroptera              4
# Coraciiformes           4
# Serpentes               3
# Sauria                  1
# Pilosa                  1
# Carcharhiniformes       1
# Orectolobiformes        1
# Name: Order, dtype: int64

# %%
ivory.shape
# Out:
# (32516, 16)

# %%
ivory[ivory['Genus']=='Mammuthus']
# Out:
# Empty DataFrame
# Columns: [Year, App., Taxon, Class, Order, Family, Genus, Importer, Exporter, Origin, Importer reported quantity, Exporter reported quantity, Term, Unit, Purpose, Source]
# Index: []

# %%
ivory.Family.value_counts()
# Out:
# Elephantidae      31763
# Odobenidae          286
# Hippopotamidae      247
# Physeteridae         69
# Monodontidae         11
# Cheloniidae           9
# Eschrichtiidae        5
# Crocodylidae          5
# Delphinidae           4
# Felidae               4
# Bovidae               3
# Pythonidae            2
# Balaenidae            2
# Tapiridae             1
# Loxocemidae           1
# Colubridae            1
# Teiidae               1
# Rhinocerotidae        1
# Orchidaceae           1
# Name: Family, dtype: int64

# %%
teeth.Family.value_counts()
# Out:
# Hippopotamidae     3030
# Ursidae             858
# Physeteridae        811
# Felidae             643
# Elephantidae        569
# Crocodylidae        544
# Monodontidae        297
# Odobenidae          261
# Delphinidae         248
# Canidae             223
# Cercopithecidae     132
# Phocoenidae          66
# Mustelidae           62
# Alligatoridae        48
# Otariidae            43
# Balaenidae           41
# Lamnidae             41
# Bovidae              35
# Tayassuidae          28
# Phocidae             26
# Rhinocerotidae       22
# Cebidae              20
# Equidae              19
# Ziphiidae            16
# Balaenopteridae      16
# Dugongidae           14
# Iniidae              14
# Dasyproctidae        13
# Pristidae            10
# Hominidae             9
# Tapiridae             6
# Pitheciidae           6
# Dasypodidae           6
# Trichechidae          5
# Atelidae              4
# Moschidae             4
# Pteropodidae          4
# Bucerotidae           4
# ...

# %%
print(ivory.shape, teeth.shape)
# Out:
# (32516, 16) (8532, 16)

# %%
ivory.Family.value_counts()
# Out:
# Elephantidae      31763
# Odobenidae          286
# Hippopotamidae      247
# Physeteridae         69
# Monodontidae         11
# Cheloniidae           9
# Eschrichtiidae        5
# Crocodylidae          5
# Delphinidae           4
# Felidae               4
# Bovidae               3
# Pythonidae            2
# Balaenidae            2
# Tapiridae             1
# Loxocemidae           1
# Colubridae            1
# Teiidae               1
# Rhinocerotidae        1
# Orchidaceae           1
# Name: Family, dtype: int64

# %%
plt.rcdefaults()
plt.rcParams.update({
    'text.color': '#ffffff',
    'lines.linewidth': 1,
    'lines.solid_capstyle': 'butt',
    'legend.fancybox': True,
    'axes.prop_cycle': cycler('color', ['#EC407A','#BBDEFB','#00E676','#90CAF9','#64B5F6','#42A5F5','#2196F3','#1DE9B6']),
    'axes.facecolor': '#222222',
    'axes.labelsize': 'large',
    'axes.labelcolor': 'white',
    'axes.axisbelow': True,
    'axes.grid': False,
    'axes.edgecolor': '222222',
    'axes.linewidth': 3.0,
    'axes.titlesize': 'x-large',
    'patch.edgecolor': '#222222',
    'patch.linewidth': 0.5,
    'svg.fonttype': 'path',
    'grid.linestyle': '-',
    'grid.linewidth': 1.0,
    'grid.color': '#cbcbcb',
    'xtick.major.size': 0,
    'xtick.minor.size': 0,
    'xtick.color': '#ffffff',
    'ytick.major.size': 0,
    'ytick.minor.size': 0,
    'ytick.color': '#ffffff',
    'font.size': 10.0,
    'savefig.edgecolor': '#222222',
    'savefig.facecolor': '#222222',
    'figure.subplot.left': 0.08,
    'figure.subplot.right': 0.95,
    'figure.subplot.bottom': 0.07,
    'figure.facecolor': '#222222',
    'ps.fonttype' : 42,
    'pdf.fonttype' : 42
})

# %%
ivory.Family.value_counts(normalize=True).plot(kind='pie')
plt.axis('equal')
plt.show()

# %%
ivory.groupby('Year')['Importer reported quantity'].sum().plot(kind='bar')
plt.show()

# %%
# ax = ivory.groupby('Year')['Exporter reported quantity'].sum().plot(kind='bar', figsize=(20,100))
# ax.invert_yaxis()
# ax.xaxis.tick_top()
# ax.xaxis.set_ticks_position('top')
# plt.show()

# %%
ivory[ivory['Year']>1991].groupby('Year')['Exporter reported quantity'].sum().plot(kind='bar')
# plt.show()

# %%
ivory[ivory['Importer reported quantity']==ivory['Exporter reported quantity']]
# Out:
#        Year App.               Taxon     Class        Order        Family  \
# 1593   1981   II  Loxodonta africana  Mammalia  Proboscidea  Elephantidae
# 2571   1982   II  Loxodonta africana  Mammalia  Proboscidea  Elephantidae
# 2705   1982   II  Loxodonta africana  Mammalia  Proboscidea  Elephantidae
# 2874   1982   II  Loxodonta africana  Mammalia  Proboscidea  Elephantidae
# 3108   1982   II  Loxodonta africana  Mammalia  Proboscidea  Elephantidae
# 3564   1983   II  Loxodonta africana  Mammalia  Proboscidea  Elephantidae
# 3805   1983   II  Loxodonta africana  Mammalia  Proboscidea  Elephantidae
# 4687   1983   II  Loxodonta africana  Mammalia  Proboscidea  Elephantidae
# 5029   1984   II  Loxodonta africana  Mammalia  Proboscidea  Elephantidae
# 5037   1984   II  Loxodonta africana  Mammalia  Proboscidea  Elephantidae
# 5064   1984   II  Loxodonta africana  Mammalia  Proboscidea  Elephantidae
# 5218   1984   II  Loxodonta africana  Mammalia  Proboscidea  Elephantidae
# ...

# %%
ivory['Importer reported quantity'].fillna(0, inplace=True)
ivory['Exporter reported quantity'].fillna(0, inplace=True)
ivory.head()
# Out:
#    Year App.              Taxon     Class        Order        Family    Genus  \
# 0  1976    I    Elephas maximus  Mammalia  Proboscidea  Elephantidae  Elephas
# 1  1977    I    Elephas maximus  Mammalia  Proboscidea  Elephantidae  Elephas
# 2  1977   II  Elephantidae spp.  Mammalia  Proboscidea  Elephantidae      NaN
# 3  1977   II  Elephantidae spp.  Mammalia  Proboscidea  Elephantidae      NaN
# 4  1977   II  Elephantidae spp.  Mammalia  Proboscidea  Elephantidae      NaN
#
#   Importer Exporter Origin  Importer reported quantity  \
# 0       DE       IN    NaN                       142.0
# 1       CA       US    NaN                         1.0
# 2       DK       GB     XX                        60.0
# 3       DK       HK     XX                        22.0
# 4       DK       IN     XX                       144.0
#
#    Exporter reported quantity            Term  Unit Purpose Source
# 0                         0.0  ivory carvings   NaN       T    NaN
# ...

# %%
ivory.dtypes
# Out:
# Year                            int64
# App.                           object
# Taxon                          object
# Class                          object
# Order                          object
# Family                         object
# Genus                          object
# Importer                       object
# Exporter                       object
# Origin                         object
# Importer reported quantity    float64
# Exporter reported quantity    float64
# Term                           object
# Unit                           object
# Purpose                        object
# Source                         object
# dtype: object

# %%
ivory.Term.value_counts()
# Out:
# ivory carvings    32516
# Name: Term, dtype: int64

# %%
ivory.Unit.value_counts()
# Out:
# kg           4157
# sets         1973
# g            1691
# pairs         244
# shipments      51
# oz             50
# boxes          10
# cases           3
# m               2
# pieces          2
# cm              1
# ml              1
# bags            1
# m3              1
# Name: Unit, dtype: int64

# %%
def kg_converter(unit, im, ex):
    if unit=='g' or unit=='cm':
        return (im/1000), (ex/1000)
    elif unit=='oz':
        return (im*0.02835), (ex*0.02835)
    else:
        return im, ex

# %% [markdown]
# Note: https://apassionatechie.wordpress.com/2017/12/27/create-multiple-pandas-dataframe-columns-from-applying-a-function-with-multiple-returns/

# %%
ivory[['im_q','ex_q']] = ivory.apply(lambda row: pd.Series(kg_converter(row['Unit'],row['Importer reported quantity'],row['Exporter reported quantity'])), axis=1)

# %%
def get_max_quantity(row):
    return max(row['im_q'], row['ex_q'])

# %%
ivory['max_quantity'] = ivory.apply(get_max_quantity, axis=1)

# %%
ivory.head(20)
# Out:
#     Year App.               Taxon     Class        Order        Family  \
# 0   1976    I     Elephas maximus  Mammalia  Proboscidea  Elephantidae
# 1   1977    I     Elephas maximus  Mammalia  Proboscidea  Elephantidae
# 2   1977   II   Elephantidae spp.  Mammalia  Proboscidea  Elephantidae
# 3   1977   II   Elephantidae spp.  Mammalia  Proboscidea  Elephantidae
# 4   1977   II   Elephantidae spp.  Mammalia  Proboscidea  Elephantidae
# 5   1977   II   Elephantidae spp.  Mammalia  Proboscidea  Elephantidae
# 6   1977   II   Elephantidae spp.  Mammalia  Proboscidea  Elephantidae
# 7   1977   II  Loxodonta africana  Mammalia  Proboscidea  Elephantidae
# 8   1977   II  Loxodonta africana  Mammalia  Proboscidea  Elephantidae
# 9   1977   II  Loxodonta africana  Mammalia  Proboscidea  Elephantidae
# 10  1977   II  Loxodonta africana  Mammalia  Proboscidea  Elephantidae
# 11  1977   II  Loxodonta africana  Mammalia  Proboscidea  Elephantidae
# ...

# %%
# ax = ivory.groupby('Year').max_quantity.sum().plot(kind='bar', color='#EC407A', figsize=(10,600))
# ax.invert_yaxis()
# ax.xaxis.tick_top()
# ax.get_yaxis().get_major_formatter().set_scientific(False)
# ax.set_yticks([0,10000,50000,100000,200000,1000000,10000000,30000000])
# ax.set_yticklabels([0,'10,000','50,000','100,000','200,000','1,000,000','10,000,000','30,000,000'])
# ax.tick_params(which='major',left=False, bottom=False, grid_alpha=0.3)
# ax.grid(True, axis='y')
# ax.set_axisbelow(True)

# plt.tight_layout()
# plt.savefig('output.svg')

# %%
ivory[ivory['Importer reported quantity']==ivory['Importer reported quantity'].max()]
# Out:
#       Year App.               Taxon     Class        Order        Family  \
# 4276  1983   II  Loxodonta africana  Mammalia  Proboscidea  Elephantidae
#
#           Genus Importer Exporter Origin  Importer reported quantity  \
# 4276  Loxodonta       JP       HK    NaN                   5981619.0
#
#       Exporter reported quantity            Term Unit Purpose Source  \
# 4276                         0.0  ivory carvings  NaN       T    NaN
#
#            im_q  ex_q  max_quantity
# 4276  5981619.0   0.0     5981619.0

# %%
ivory[ivory['Exporter reported quantity']==ivory['Exporter reported quantity'].max()]
# Out:
#        Year App.               Taxon     Class        Order        Family  \
# 10613  1987   II  Loxodonta africana  Mammalia  Proboscidea  Elephantidae
#
#            Genus Importer Exporter Origin  Importer reported quantity  \
# 10613  Loxodonta       HK       CN     CF                         0.0
#
#        Exporter reported quantity            Term Unit Purpose Source  im_q  \
# 10613                  21648201.0  ivory carvings  NaN     NaN    NaN   0.0
#
#              ex_q  max_quantity
# 10613  21648201.0    21648201.0

# %% [markdown]
# We ran out of luck. Data without unit is tough; you can't do anything about it. Below I try to filter out rows without a unit.

# %%
ivory_filtered = ivory[ivory['Unit'].notnull()]
ivory_filtered.head()
# Out:
#    Year App.              Taxon     Class        Order        Family Genus  \
# 2  1977   II  Elephantidae spp.  Mammalia  Proboscidea  Elephantidae   NaN
# 3  1977   II  Elephantidae spp.  Mammalia  Proboscidea  Elephantidae   NaN
# 4  1977   II  Elephantidae spp.  Mammalia  Proboscidea  Elephantidae   NaN
# 5  1977   II  Elephantidae spp.  Mammalia  Proboscidea  Elephantidae   NaN
# 6  1977   II  Elephantidae spp.  Mammalia  Proboscidea  Elephantidae   NaN
#
#   Importer Exporter Origin  Importer reported quantity  \
# 2       DK       GB     XX                        60.0
# 3       DK       HK     XX                        22.0
# 4       DK       IN     XX                       144.0
# 5       DK       TH     XX                       100.0
# 6       DK       ZM    NaN                         8.0
#
#    Exporter reported quantity            Term  Unit Purpose Source   im_q  \
# 2                         0.0  ivory carvings  sets     NaN    NaN   60.0
# ...

# %%
ivory_filtered[ivory_filtered['max_quantity']==ivory_filtered['max_quantity'].max()]
# Out:
#        Year App.               Taxon     Class        Order        Family  \
# 10188  1987   II  Loxodonta africana  Mammalia  Proboscidea  Elephantidae
#
#            Genus Importer Exporter Origin  Importer reported quantity  \
# 10188  Loxodonta       DE       HK     ZA                   1011461.0
#
#        Exporter reported quantity            Term Unit Purpose Source  \
# 10188                         0.0  ivory carvings   kg       T    NaN
#
#             im_q  ex_q  max_quantity
# 10188  1011461.0   0.0     1011461.0

# %%
ax = ivory_filtered.groupby('Year').max_quantity.sum().plot(kind='bar', color='#EC407A', figsize=(2,120))
ax.invert_yaxis()
ax.xaxis.tick_top()

ax.get_yaxis().get_major_formatter().set_scientific(False)
# Sometimes the above line will only work once. Why?

ax.set_yticks([0,10000,50000,100000,200000,1000000])
ax.set_yticklabels([0,'10,000','50,000','100,000','200,000','1,000,000'])

ax.set_ylim(1011462,0)
# Note the syntax: ax.set_ylim(bottom, top)
# If you do it like ax.set_ylim(0,1011462) it'll cancel out ax.invert_yaxis()!

ax.tick_params(which='major',left=False, bottom=False, grid_alpha=0.3)
ax.grid(True, axis='y')
ax.set_axisbelow(True)

plt.tight_layout()
plt.savefig('new_output.pdf')

plt.show()

# %%
ivory_filtered.groupby('Year').max_quantity.sum()
# Out:
# Year
# 1977    5.864300e+03
# 1978    3.659434e+03
# 1979    2.818208e+04
# 1980    2.580967e+04
# 1981    1.105833e+05
# 1982    1.865089e+05
# 1983    4.987100e+05
# 1984    8.161037e+04
# 1985    4.339310e+05
# 1986    5.382567e+05
# 1987    1.055920e+06
# 1988    4.599820e+04
# 1989    8.271943e+04
# 1990    3.146590e+04
# 1991    2.577802e+04
# 1992    6.513510e+02
# 1993    2.260430e+02
# 1994    6.744810e+02
# 1995    1.072470e+02
# 1996    1.067417e+03
# 1997    2.866600e+02
# 1998    5.629859e+02
# 1999    2.935600e+02
# 2000    4.026700e+02
# 2001    2.777215e+02
# 2002    3.964250e+02
# 2003    7.919050e+02
# 2004    1.034883e+03
# 2005    1.410695e+03
# 2006    3.691600e+02
# 2007    6.724670e+02
# 2008    6.004030e+02
# 2009    1.253180e+02
# 2010    2.917170e+01
# 2011    3.259592e+03
# 2012    3.251923e+03
# 2013    3.564668e+03
# 2014    8.669116e+03
# 2015    2.513880e+02
# 2016    2.636547e+02
# Name: max_quantity, dtype: float64
